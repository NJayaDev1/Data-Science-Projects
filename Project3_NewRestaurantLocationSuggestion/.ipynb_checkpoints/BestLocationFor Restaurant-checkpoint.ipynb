# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

import json # library to handle JSON files

import seaborn as sns

# %%
#!conda install -c conda-forge geopy --yes 
# uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %%
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %%
# !conda update -n base -c defaults conda
# Out:
# ^C

# %%
import certifi
import ssl
import geopy.geocoders

# %% [markdown]
# # Getting data and loading data

# %%
# !wget -q -O "newyorkCity_data.json" https://ibm.box.com/shared/static/fbpwbovar7lf8p5sgddm06cgipa2rxpe.json
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyorkCity_data.json') as json_data:
    newyorkCity_data = json.load(json_data)

# %%
type(newyorkCity_data)
# Out:
# dict

# %%
neighborhoods_data=newyorkCity_data['features']
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %%
type(neighborhoods_data)
# Out:
# list

# %% [markdown]
# # Transforming data into dataframe

# %%
#define the pandas data frame column
column_names = ['Borough', 'Neighboorhood', 'Latitude', 'Longitude']

#Assign columns to empty dataframe
neighborhoods = pd.DataFrame(columns=column_names)
#print(type(neighborhoods_data), neighborhoods_data.head())

# %% [raw]
# Storing the data into a dataframe

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']  
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %% [raw]
# As we are planning to open restaurant in Manhattan. Slicing the Newyork Dataframe and storing only Manhattan Details

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough  Neighboorhood   Latitude  Longitude        Neighborhood
# 0  Manhattan            NaN  40.876551 -73.910660         Marble Hill
# 1  Manhattan            NaN  40.715618 -73.994279           Chinatown
# 2  Manhattan            NaN  40.851903 -73.936900  Washington Heights
# 3  Manhattan            NaN  40.867684 -73.921210              Inwood
# 4  Manhattan            NaN  40.823604 -73.949688    Hamilton Heights

# %%
sns.heatmap(manhattan_data.isnull())

# %% [raw]
# Find the geo co-ordinates of Manhattan city and draw a map for visualizing all neighbors in Manahattan

# %%
address = 'Manhattan, NY'

ssl._create_default_https_context = ssl._create_unverified_context

geolocator = Nominatim(user_agent="my", scheme = 'http')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 976             conn.connect()
#     977
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     360
# --> 361         self.sock = ssl_wrap_socket(
#     362             sock=conn,
#
# ...

# %%
latitude = 40.7831
longitude = 73.9712

# %%
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [raw]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them.
#
# Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'YUWOO1JLRIVU0R40QZ05IODMDMDD54DX3DVH5SEXLSZKU5F4' # your Foursquare ID
CLIENT_SECRET = 'KEHYSKHETV4KGPOBLXX3WGGDNR4LGPFKY1Z3WS2PAJPQWZQL' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT=50
latitude = 40.7831
longitude = 73.9712
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YUWOO1JLRIVU0R40QZ05IODMDMDD54DX3DVH5SEXLSZKU5F4
# CLIENT_SECRET:KEHYSKHETV4KGPOBLXX3WGGDNR4LGPFKY1Z3WS2PAJPQWZQL

# %%
search_query = 'restaurant'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=YUWOO1JLRIVU0R40QZ05IODMDMDD54DX3DVH5SEXLSZKU5F4&client_secret=KEHYSKHETV4KGPOBLXX3WGGDNR4LGPFKY1Z3WS2PAJPQWZQL&ll=40.7831,73.9712&v=20180605&query=restaurant&radius=5000&limit=50'

# %%
import requests
results = requests.get(url).json()
results
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
